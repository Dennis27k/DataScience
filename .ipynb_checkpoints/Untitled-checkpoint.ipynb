# %%
import pandas as pd
import numpy as np

# %%
pd.__version__
# Out:
# '1.0.1'

# %%
covid19 = pd.read_csv("Anaconda/RKI_COVID19.csv")

# %%
covid19.head()
# Out:
#         FID  IdBundesland          Bundesland     Landkreis Altersgruppe  \
# 0  10110919             1  Schleswig-Holstein  SK Flensburg      A15-A34
# 1  10110920             1  Schleswig-Holstein  SK Flensburg      A15-A34
# 2  10110921             1  Schleswig-Holstein  SK Flensburg      A15-A34
# 3  10110922             1  Schleswig-Holstein  SK Flensburg      A15-A34
# 4  10110923             1  Schleswig-Holstein  SK Flensburg      A15-A34
#
#   Geschlecht  AnzahlFall  AnzahlTodesfall           Meldedatum  IdLandkreis  \
# 0          M           1                0  2020/03/14 00:00:00         1001
# 1          M           1                0  2020/03/19 00:00:00         1001
# 2          M           1                0  2020/03/19 00:00:00         1001
# 3          M           1                0  2020/03/21 00:00:00         1001
# 4          M           1                0  2020/03/27 00:00:00         1001
#
# ...

# %%
type(covid19)
# Out:
# pandas.core.frame.DataFrame

# %%
covid19.columns
# Out:
# Index(['FID', 'IdBundesland', 'Bundesland', 'Landkreis', 'Altersgruppe',
#        'Geschlecht', 'AnzahlFall', 'AnzahlTodesfall', 'Meldedatum',
#        'IdLandkreis', 'Datenstand', 'NeuerFall', 'NeuerTodesfall', 'Refdatum',
#        'NeuGenesen', 'AnzahlGenesen', 'IstErkrankungsbeginn', 'Altersgruppe2'],
#       dtype='object')

# %%
covid19[covid19['Landkreis'].str.contains('ü')]
# Out:
#              FID  IdBundesland          Bundesland            Landkreis  \
# 305     10111224             1  Schleswig-Holstein            SK Lübeck
# 306     10111225             1  Schleswig-Holstein            SK Lübeck
# 307     10111226             1  Schleswig-Holstein            SK Lübeck
# 308     10111227             1  Schleswig-Holstein            SK Lübeck
# 309     10111228             1  Schleswig-Holstein            SK Lübeck
# ...          ...           ...                 ...                  ...
# 142773  10253692            15      Sachsen-Anhalt  LK Mansfeld-Südharz
# 142774  10253693            15      Sachsen-Anhalt  LK Mansfeld-Südharz
# 142775  10253694            15      Sachsen-Anhalt  LK Mansfeld-Südharz
# 142776  10253695            15      Sachsen-Anhalt  LK Mansfeld-Südharz
# 142777  10253696            15      Sachsen-Anhalt  LK Mansfeld-Südharz
#
#        Altersgruppe Geschlecht  AnzahlFall  AnzahlTodesfall  \
# ...

# %%
einwohner = pd.read_csv("Anaconda/12411_0016_edited.csv", encoding='utf8', delimiter=";")
einwohner[einwohner[['Insgesamt']] == 'NaN'] = np.nan

# %%
einwohner
# Out:
#                                               Stichtag       ID  \
# 0                                           31.12.2018   1001.0
# 1                                           31.12.2018   1002.0
# 2                                           31.12.2018   1003.0
# 3                                           31.12.2018   1004.0
# 4                                           31.12.2018   1051.0
# ..                                                 ...      ...
# 475                                         31.12.2018  16077.0
# 476                                         __________      NaN
# 477  Ab 2011: Ergebnisse auf Grundlage des Zensus 2...      NaN
# 478         © Statistisches Bundesamt (Destatis), 2020      NaN
# 479                       Stand: 02.06.2020 / 12:33:16      NaN
#
#                            Kreise männlich weiblich Insgesamt
# 0     Flensburg, kreisfreie Stadt    44599    44905     89504
# 1          Kiel, kreisfreie Stadt   120566   126982    247548
# ...

# %%
covid19.groupby(['IdLandkreis', 'Landkreis', 'IdBundesland']).sum()
# Out:
#                                                          FID  AnzahlFall  \
# IdLandkreis Landkreis               IdBundesland
# 1001        SK Flensburg            1              414548499          42
# 1002        SK Kiel                 1             2669328156         279
# 1003        SK Lübeck               1             1577363034         169
# 1004        SK Neumünster           1              758356275          79
# 1051        LK Dithmarschen         1              566243020          59
# ...                                                      ...         ...
# 16073       LK Saalfeld-Rudolstadt  16             697412998          71
# 16074       LK Saale-Holzland-Kreis 16             646136757          71
# 16075       LK Saale-Orla-Kreis     16            1394848436         148
# 16076       LK Greiz                16            5753945307         625
# 16077       LK Altenburger Land     16             707726238          71
#
# ...

# %%
einwohner
# Out:
#                                               Stichtag       ID  \
# 0                                           31.12.2018   1001.0
# 1                                           31.12.2018   1002.0
# 2                                           31.12.2018   1003.0
# 3                                           31.12.2018   1004.0
# 4                                           31.12.2018   1051.0
# ..                                                 ...      ...
# 475                                         31.12.2018  16077.0
# 476                                         __________      NaN
# 477  Ab 2011: Ergebnisse auf Grundlage des Zensus 2...      NaN
# 478         © Statistisches Bundesamt (Destatis), 2020      NaN
# 479                       Stand: 02.06.2020 / 12:33:16      NaN
#
#                            Kreise männlich weiblich Insgesamt
# 0     Flensburg, kreisfreie Stadt    44599    44905     89504
# 1          Kiel, kreisfreie Stadt   120566   126982    247548
# ...

# %%
einwohner.loc[einwohner['ID'] == 1001]
# Out:
#      Stichtag      ID                       Kreise männlich weiblich Insgesamt
# 0  31.12.2018  1001.0  Flensburg, kreisfreie Stadt    44599    44905     89504

# %%
covid19.loc[covid19['IdLandkreis'] == 1001]
# Out:
#          FID  IdBundesland          Bundesland     Landkreis Altersgruppe  \
# 0   10110919             1  Schleswig-Holstein  SK Flensburg      A15-A34
# 1   10110920             1  Schleswig-Holstein  SK Flensburg      A15-A34
# 2   10110921             1  Schleswig-Holstein  SK Flensburg      A15-A34
# 3   10110922             1  Schleswig-Holstein  SK Flensburg      A15-A34
# 4   10110923             1  Schleswig-Holstein  SK Flensburg      A15-A34
# 5   10110924             1  Schleswig-Holstein  SK Flensburg      A15-A34
# 6   10110925             1  Schleswig-Holstein  SK Flensburg      A15-A34
# 7   10110926             1  Schleswig-Holstein  SK Flensburg      A15-A34
# 8   10110927             1  Schleswig-Holstein  SK Flensburg      A15-A34
# 9   10110928             1  Schleswig-Holstein  SK Flensburg      A15-A34
# 10  10110929             1  Schleswig-Holstein  SK Flensburg      A15-A34
# 11  10110930             1  Schleswig-Holstein  SK Flensburg      A15-A34
# ...

# %%
mergeSet = pd.merge(covid19.groupby(['IdLandkreis', 'Landkreis']).sum(), einwohner, left_on = 'IdLandkreis', right_on = 'ID')

# %%
mergeSet
# Out:
#             FID  IdBundesland  AnzahlFall  AnzahlTodesfall  NeuerFall  \
# 0     414548499            41          42                3          0
# 1    2669328156           264         279                9          0
# 2    1577363034           156         169                1          2
# 3     758356275            75          79                2          0
# 4     566243020            56          59                3          0
# ..          ...           ...         ...              ...        ...
# 395   697412998          1088          71                0          0
# 396   646136757          1008          71                3          0
# 397  1394848436          2176         148               12          1
# 398  5753945307          8976         625               45          0
# 399   707726238          1104          71                3          0
#
#      NeuerTodesfall  NeuGenesen  AnzahlGenesen  IstErkrankungsbeginn  \
# ...

# %%
corMatrix = mergeSet[['Kreise', 'Insgesamt']]

# %%
print(corMatrix.corr())
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
mergeSet[['Kreise', 'Insgesamt', 'AnzahlFall']]
# Out:
#                              Kreise Insgesamt  AnzahlFall
# 0       Flensburg, kreisfreie Stadt     89504          42
# 1            Kiel, kreisfreie Stadt    247548         279
# 2          Lübeck, kreisfreie Stadt    217198         169
# 3      Neumünster, kreisfreie Stadt     79487          79
# 4           Dithmarschen, Landkreis    133210          59
# ..                              ...       ...         ...
# 395  Saalfeld-Rudolstadt, Landkreis    106356          71
# 396            Saale-Holzland-Kreis     83051          71
# 397                Saale-Orla-Kreis     80868         148
# 398                Greiz, Landkreis     98159         625
# 399     Altenburger Land, Landkreis     90118          71
#
# [400 rows x 3 columns]

# %%
mergeSet
# Out:
#             FID  IdBundesland  AnzahlFall  AnzahlTodesfall  NeuerFall  \
# 0     414548499            41          42                3          0
# 1    2669328156           264         279                9          0
# 2    1577363034           156         169                1          2
# 3     758356275            75          79                2          0
# 4     566243020            56          59                3          0
# ..          ...           ...         ...              ...        ...
# 395   697412998          1088          71                0          0
# 396   646136757          1008          71                3          0
# 397  1394848436          2176         148               12          1
# 398  5753945307          8976         625               45          0
# 399   707726238          1104          71                3          0
#
#      NeuerTodesfall  NeuGenesen  AnzahlGenesen  IstErkrankungsbeginn  \
# ...

# %%
mergeSet[['AnzahlFall']].corr()
# Out:
#             AnzahlFall
# AnzahlFall         1.0

# %%
einwohner.corr()
# Out:
#      ID
# ID  1.0

# %%
einwohner
# Out:
#                                               Stichtag       ID  \
# 0                                           31.12.2018   1001.0
# 1                                           31.12.2018   1002.0
# 2                                           31.12.2018   1003.0
# 3                                           31.12.2018   1004.0
# 4                                           31.12.2018   1051.0
# ..                                                 ...      ...
# 475                                         31.12.2018  16077.0
# 476                                         __________      NaN
# 477  Ab 2011: Ergebnisse auf Grundlage des Zensus 2...      NaN
# 478         © Statistisches Bundesamt (Destatis), 2020      NaN
# 479                       Stand: 02.06.2020 / 12:33:16      NaN
#
#                            Kreise männlich weiblich Insgesamt
# 0     Flensburg, kreisfreie Stadt    44599    44905     89504
# 1          Kiel, kreisfreie Stadt   120566   126982    247548
# ...

# %%
test = np.nan

# %%
test
# Out:
# nan

# %%
mergeSet
# Out:
#             FID  IdBundesland  AnzahlFall  AnzahlTodesfall  NeuerFall  \
# 0     414548499            41          42                3          0
# 1    2669328156           264         279                9          0
# 2    1577363034           156         169                1          2
# 3     758356275            75          79                2          0
# 4     566243020            56          59                3          0
# ..          ...           ...         ...              ...        ...
# 395   697412998          1088          71                0          0
# 396   646136757          1008          71                3          0
# 397  1394848436          2176         148               12          1
# 398  5753945307          8976         625               45          0
# 399   707726238          1104          71                3          0
#
#      NeuerTodesfall  NeuGenesen  AnzahlGenesen  IstErkrankungsbeginn  \
# ...

# %%
einwohner.loc[einwohner['ID'] == 3152]
# Out:
#       Stichtag      ID                                 Kreise männlich  \
# 20  31.12.2018  3152.0  Göttingen, Landkreis (bis 31.10.2016)        -
#
#    weiblich Insgesamt
# 20        -         -

# %%
einwohner[['Insgesamt']]
# Out:
#     Insgesamt
# 0       89504
# 1      247548
# 2      217198
# 3       79487
# 4      133210
# ..        ...
# 475     90118
# 476       NaN
# 477       NaN
# 478       NaN
# 479       NaN
#
# [480 rows x 1 columns]

# %%
mergeSet['testSpalte'] = mergeSet['ID'] / 10

# %%
mergeSet
# Out:
#             FID  IdBundesland  AnzahlFall  AnzahlTodesfall  NeuerFall  \
# 0     414548499            41          42                3          0
# 1    2669328156           264         279                9          0
# 2    1577363034           156         169                1          2
# 3     758356275            75          79                2          0
# 4     566243020            56          59                3          0
# ..          ...           ...         ...              ...        ...
# 395   697412998          1088          71                0          0
# 396   646136757          1008          71                3          0
# 397  1394848436          2176         148               12          1
# 398  5753945307          8976         625               45          0
# 399   707726238          1104          71                3          0
#
#      NeuerTodesfall  NeuGenesen  AnzahlGenesen  IstErkrankungsbeginn  \
# ...
